# %% [markdown]
# @Author: Naziya
#
# @Date: 2021-07-30
#
# @Last Modified by: Naziya
#
# @Last Modified : 2021-07-30
#
# @Title : Program Aim is to draw a swarm plot of total bill against size for a dataset given in a url.

# %%
import seaborn as sns
from LoggerFormat import logger
import pandas as pd

try:
    data = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
    sns.swarmplot(x="size",y="total_bill", data=data)
     
except Exception as err:
    logger.error(err)
# Out:
# /home/naziya/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 17.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
