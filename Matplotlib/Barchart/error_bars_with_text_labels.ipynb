# %% [markdown]
# @Author: Naziya
#
# @Date: 2021-07-29
#
# @Last Modified by: Naziya
#
# @Last Modified : 2021-07-29
#
# @Title : Program Aim is to create bar plots with error bars on the same figure.Attach a text
#          label above each bar displaying men means (integer value).

# %%
import matplotlib.pyplot as plt
from LoggerFormat import logger
import numpy as np
import matplotlib.patches as mpatches

try:
    mean_velocity = (54.74, 42.35, 67.37, 58.24, 30.25)
    sd_of_velocity = (4, 3, 4, 1, 5)
    index = np.arange(len(mean_velocity))
    fig,ax = plt.subplots()
    rects1 = ax.bar(index,mean_velocity,width=0.35,color="orange",yerr = sd_of_velocity)

    plt.xlabel("Velocity")
    plt.ylabel("scores")
    plt.title("Scores by Velocity")

    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

    red_patch = mpatches.Patch(color='orange', label='Men')
    plt.legend(handles=[red_patch])

    for rect in rects1:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),ha='center', va='bottom')
    

except Exception as err:
    logger.error(err)
