# %% [markdown]
# @Author: Naziya
#
# @Date: 2021-07-28
#
# @Last Modified by: Naziya
#
# @Last Modified : 2021-07-28
#
# @Title : Program Aim is to draw a line using given axis values with suitable label in the x axis
#          , y axis and a title

# %%
from matplotlib import pyplot as plt
from LoggerFormat import logger

try:
    x=[1,2,3,]
    y=[2,6,3,]
    plt.plot(x,y)
    plt.xlabel("x-axis")
    plt.ylabel("y-axis")
    plt.title("Draw a line")
    plt.show()
except Exception as err:
    logger.error(err)
