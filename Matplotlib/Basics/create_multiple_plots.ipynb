# %% [markdown]
# @Author: Naziya
#
# @Date: 2021-07-29
#
# @Last Modified by: Naziya
#
# @Last Modified : 2021-07-29
#
# @Title : Program Aim is to create multiple plots

# %%
import matplotlib.pyplot as plt
from LoggerFormat import logger
import numpy as np

# %%
try:
    x1 = np.array([1, 2, 3])
    y1 = np.array([4, 5, 6])
    x2 = np.array([1, 2])
    y2 = np.array([2, 1])

    plt.subplot(1,2,1)
    plt.plot(x1,y1)

    plt.subplot(1,2,2)
    plt.plot(x2,y2)


except Exception as err:
    logger.error(err)
